# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv("../data/cars_data.csv")
df2 = pd.read_csv("../data/cars_data2.csv")

# %%
df1.head()
# Out:
#                                       Name           Price  Năm SX Tình trạng  \
# 0        Mercedes-Benz GLC 200 4Matic 2021  1 tỉ 389 triệu    2021      Xe cũ
# 1                 Lexus RX 350 Luxury 2016  2 tỉ 099 triệu    2016      Xe cũ
# 2               Kia Sonet 1.5 Premium 2024       585 triệu    2024      Xe cũ
# 3   Ford Everest Titanium 2.0L AT 4WD 2019       810 triệu    2019      Xe cũ
# 4  Mercedes-Benz S450 Limited Edition 2020  2 tỉ 398 triệu    2020      Xe cũ
#
#       Xuất xứ    Km đã đi Tỉnh thành   Quận huyện      Hộp số Nhiên liệu  ...  \
# 0  Trong nước   55.555 km     Tp.HCM       Quận 7  Số tự động   Máy xăng  ...
# 1   Nhập khẩu  130.000 km     Hà Nội      Ba Đình  Số tự động   Máy xăng  ...
# 2  Trong nước    1.000 km     Hà Nội  Nam Từ Liêm  Số tự động   Máy xăng  ...
# 3   Nhập khẩu       04 km     Tp.HCM          NaN  Số tự động   Máy xăng  ...
# 4  Trong nước   46.000 km     Tp.HCM       Quận 7  Số tự động   Máy xăng  ...
#
#   Hỗ trợ trả góp Bảo hành máy móc động cơ 3-6 tháng Một chủ từ đầu  \
# 0            NaN                                NaN            NaN
# 1            NaN                                NaN            NaN
# 2            NaN                                NaN            NaN
# 3            NaN                                NaN            NaN
# 4            NaN                                NaN            NaN
#
#   Full lịch sử hãng Thủ tục trọn gói (Rút hồ sơ,sang tên,...) Model xe mới  \
# 0               NaN                                       NaN          NaN
# 1               NaN                                       NaN          NaN
# 2               NaN                                       NaN          NaN
# 3               NaN                                       NaN          NaN
# 4               NaN                                       NaN          NaN
#
#   Xe có nhiều đồ chơi Hỗ trợ/cam kết từ người bán Có xuất hóa đơn  \
# 0                 NaN                               NaN             NaN
# 1                 NaN                               NaN             NaN
# 2                 NaN                               NaN             NaN
# 3                 NaN                               NaN             NaN
# 4                 NaN                               NaN             NaN
#
#   Còn bảo hiểm thân vỏ
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 26 columns]

# %%
df2.head()
# Out:
#                                                 Name  Năm sản xuất  \
# 0  Xe \n\t\t\t\n\t\t\t\t\t\t\tMercedes Benz GLC \...          2021
# 1  Xe \n\t\t\t\n\t\t\t\t\t\t\tKia Sedona \n\t\t\t...          2021
# 2  Xe \n\t\t\t\n\t\t\t\t\t\t\tMercedes Benz C cla...          2015
# 3  Xe \n\t\t\t\n\t\t\t\t\t\t\tSuzuki XL7 \n\t\t\t...          2022
# 4  Xe \n\t\t\t\n\t\t\t\t\t\t\tMercedes Benz C cla...          2015
#
#    Tình trạng Số Km đã đi             Xuất xứ    Kiểu dáng      Động cơ  \
# 0  Xe đã dùng   60,000 Km  Lắp ráp trong nước          SUV  Xăng  2.0 L
# 1  Xe đã dùng   96,000 Km  Lắp ráp trong nước  Van/Minivan   Dầu  2.2 L
# 2  Xe đã dùng   70,000 Km  Lắp ráp trong nước        Sedan  Xăng  2.0 L
# 3  Xe đã dùng   65,000 Km           Nhập khẩu          SUV  Xăng  1.5 L
# 4  Xe đã dùng   89,000 Km  Lắp ráp trong nước        Sedan  Xăng  2.0 L
#
#   Màu ngoại thất Màu nội thất
# 0          Trắng          Đen
# 1          Trắng          Nâu
# 2            Đen          Đen
# 3          Trắng          Nâu
# 4            Đen          Kem

# %% [markdown]
# ### clean df1

# %%
for i in df1.columns :
    print(f"{i} : {df1[i].nunique()}")
# Out:
# Name : 1119
# Price : 584
# Năm SX : 24
# Tình trạng : 1
# Xuất xứ : 2
# Km đã đi : 312
# Tỉnh thành : 42
# Quận huyện : 91
# Hộp số : 2
# Nhiên liệu : 4
# Số tiền vay : 1
# Thời gian vay : 1
# Lãi xuất (%) : 1
# Loại hình : 1
# Giá trị xe muốn mua : 1
# Kiểu dáng : 11
# Hỗ trợ trả góp : 3
# Bảo hành máy móc động cơ 3-6 tháng : 2
# Một chủ từ đầu : 2
# Full lịch sử hãng : 3
# Thủ tục trọn gói (Rút hồ sơ,sang tên,...) : 3
# Model xe mới : 3
# Xe có nhiều đồ chơi : 3
# Hỗ trợ/cam kết từ người bán : 3
# Có xuất hóa đơn : 1
# Còn bảo hiểm thân vỏ : 1

# %%
df1 = df1.loc[:, df1.nunique() > 1]

# %%
threshold = 0.5
df1 = df1.loc[:, df1.isnull().mean() < threshold]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1490 entries, 0 to 1489
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        1490 non-null   object
#  1   Price       1490 non-null   object
#  2   Năm SX      1490 non-null   int64
#  3   Xuất xứ     1483 non-null   object
#  4   Km đã đi    1485 non-null   object
#  5   Tỉnh thành  1490 non-null   object
#  6   Quận huyện  1285 non-null   object
#  7   Hộp số      1490 non-null   object
#  8   Nhiên liệu  1490 non-null   object
#  9   Kiểu dáng   1352 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 116.5+ KB

# %%
df1.rename(columns={
    'Name': 'Name',
    'Price': 'Price',
    'Năm SX': 'Year',
    'Kiểu dáng': 'Body_Type',
    'Xuất xứ': 'Origin',
    'Km đã đi': 'Mileage',
    'Tỉnh thành': 'Province',
    'Quận huyện': 'District',
    'Hộp số': 'Transmission',
    'Nhiên liệu': 'Fuel_Type'
}, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1490 entries, 0 to 1489
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          1490 non-null   object
#  1   Price         1490 non-null   object
#  2   Year          1490 non-null   int64
#  3   Origin        1483 non-null   object
#  4   Mileage       1485 non-null   object
#  5   Province      1490 non-null   object
#  6   District      1285 non-null   object
#  7   Transmission  1490 non-null   object
#  8   Fuel_Type     1490 non-null   object
#  9   Body_Type     1352 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 116.5+ KB

# %%
df1.isna().sum()
# Out:
# Name              0
# Price             0
# Year              0
# Origin            7
# Mileage           5
# Province          0
# District        205
# Transmission      0
# Fuel_Type         0
# Body_Type       138
# dtype: int64

# %%
df1.head()
# Out:
#                                       Name           Price  Year      Origin  \
# 0        Mercedes-Benz GLC 200 4Matic 2021  1 tỉ 389 triệu  2021  Trong nước
# 1                 Lexus RX 350 Luxury 2016  2 tỉ 099 triệu  2016   Nhập khẩu
# 2               Kia Sonet 1.5 Premium 2024       585 triệu  2024  Trong nước
# 3   Ford Everest Titanium 2.0L AT 4WD 2019       810 triệu  2019   Nhập khẩu
# 4  Mercedes-Benz S450 Limited Edition 2020  2 tỉ 398 triệu  2020  Trong nước
#
#       Mileage Province     District Transmission Fuel_Type  Body_Type
# 0   55.555 km   Tp.HCM       Quận 7   Số tự động  Máy xăng        NaN
# 1  130.000 km   Hà Nội      Ba Đình   Số tự động  Máy xăng        SUV
# 2    1.000 km   Hà Nội  Nam Từ Liêm   Số tự động  Máy xăng  Crossover
# 3       04 km   Tp.HCM          NaN   Số tự động  Máy xăng        SUV
# 4   46.000 km   Tp.HCM       Quận 7   Số tự động  Máy xăng      Sedan

# %% [markdown]
# 1. Name

# %%
df1.Name.head()
# Out:
# 0          Mercedes-Benz GLC 200 4Matic 2021
# 1                   Lexus RX 350 Luxury 2016
# 2                 Kia Sonet 1.5 Premium 2024
# 3     Ford Everest Titanium 2.0L AT 4WD 2019
# 4    Mercedes-Benz S450 Limited Edition 2020
# Name: Name, dtype: object

# %%
df1["Brand"] = df1["Name"].str.strip().str.split().str[0]

# %%
df1.head()
# Out:
#                                       Name           Price  Year      Origin  \
# 0        Mercedes-Benz GLC 200 4Matic 2021  1 tỉ 389 triệu  2021  Trong nước
# 1                 Lexus RX 350 Luxury 2016  2 tỉ 099 triệu  2016   Nhập khẩu
# 2               Kia Sonet 1.5 Premium 2024       585 triệu  2024  Trong nước
# 3   Ford Everest Titanium 2.0L AT 4WD 2019       810 triệu  2019   Nhập khẩu
# 4  Mercedes-Benz S450 Limited Edition 2020  2 tỉ 398 triệu  2020  Trong nước
#
#       Mileage Province     District Transmission Fuel_Type  Body_Type  \
# 0   55.555 km   Tp.HCM       Quận 7   Số tự động  Máy xăng        NaN
# 1  130.000 km   Hà Nội      Ba Đình   Số tự động  Máy xăng        SUV
# 2    1.000 km   Hà Nội  Nam Từ Liêm   Số tự động  Máy xăng  Crossover
# 3       04 km   Tp.HCM          NaN   Số tự động  Máy xăng        SUV
# 4   46.000 km   Tp.HCM       Quận 7   Số tự động  Máy xăng      Sedan
#
#            Brand
# 0  Mercedes-Benz
# 1          Lexus
# 2            Kia
# 3           Ford
# 4  Mercedes-Benz

# %% [markdown]
# 2.Price

# %%
df1.Price.head()
# Out:
# 0    1 tỉ 389 triệu
# 1    2 tỉ 099 triệu
# 2         585 triệu
# 3         810 triệu
# 4    2 tỉ 398 triệu
# Name: Price, dtype: object

# %%
def convert_price(price_str):
    price_str = price_str.strip().lower()
    price = 0
    if "tỉ" in price_str:
        parts = price_str.split("tỉ")
        ty = int(parts[0].strip())
        price += ty * 1_000_000_000
        if "triệu" in parts[1]:
            trieu = int(parts[1].replace("triệu", "").strip())
            price += trieu * 1_000_000
    elif "triệu" in price_str:
        trieu = int(price_str.replace("triệu", "").strip())
        price += trieu * 1_000_000
    return price

df1["price_num"] = df1["Price"].apply(convert_price)

# %%
df1.head()
# Out:
#                                       Name           Price  Year      Origin  \
# 0        Mercedes-Benz GLC 200 4Matic 2021  1 tỉ 389 triệu  2021  Trong nước
# 1                 Lexus RX 350 Luxury 2016  2 tỉ 099 triệu  2016   Nhập khẩu
# 2               Kia Sonet 1.5 Premium 2024       585 triệu  2024  Trong nước
# 3   Ford Everest Titanium 2.0L AT 4WD 2019       810 triệu  2019   Nhập khẩu
# 4  Mercedes-Benz S450 Limited Edition 2020  2 tỉ 398 triệu  2020  Trong nước
#
#       Mileage Province     District Transmission Fuel_Type  Body_Type  \
# 0   55.555 km   Tp.HCM       Quận 7   Số tự động  Máy xăng        NaN
# 1  130.000 km   Hà Nội      Ba Đình   Số tự động  Máy xăng        SUV
# 2    1.000 km   Hà Nội  Nam Từ Liêm   Số tự động  Máy xăng  Crossover
# 3       04 km   Tp.HCM          NaN   Số tự động  Máy xăng        SUV
# 4   46.000 km   Tp.HCM       Quận 7   Số tự động  Máy xăng      Sedan
#
#            Brand   price_num
# 0  Mercedes-Benz  1389000000
# 1          Lexus  2099000000
# 2            Kia   585000000
# 3           Ford   810000000
# 4  Mercedes-Benz  2398000000

# %%
df1 = df1.drop("Price",axis=1)

# %%
Q1 = df1['price_num'].quantile(0.25)
Q3 = df1['price_num'].quantile(0.75)
IQR = Q3 - Q1

df1 = df1[(df1['price_num'] >= Q1 - 1.5 * IQR) & (df1['price_num'] <= Q3 + 1.5 * IQR)]

# %% [markdown]
# 3.Year

# %%
df1.Year.head()
# Out:
# 0    2021
# 2    2024
# 3    2019
# 6    2016
# 7    2017
# Name: Year, dtype: int64

# %%
df1.Year = df1.Year.astype(int)

# %%
df1["age"] = 2025 - df1["Year"]

# %% [markdown]
# 4.Body_Type

# %%
df1.Body_Type.unique()
# Out:
# array([nan, 'Crossover', 'SUV', 'Sedan', 'Bán tải', 'MPV', 'Hatchback',
#        'Van/Minivan', 'Xe tải', 'Sport Car', 'Convertible', 'Coupe'],
#       dtype=object)

# %%
df1.Body_Type.value_counts()
# Out:
# Body_Type
# SUV            406
# Sedan          402
# Hatchback      108
# Bán tải        101
# MPV             99
# Van/Minivan     36
# Crossover       34
# Xe tải           8
# Sport Car        3
# Convertible      3
# Coupe            2
# Name: count, dtype: int64

# %%
df1.loc[df1["Body_Type"].isna() , "Body_Type"] = "Other"

# %% [markdown]
# 5.Origin

# %%
df1.Origin.isna().sum()
# Out:
# 7

# %%
df1.Origin.value_counts()
# Out:
# Origin
# Trong nước    824
# Nhập khẩu     484
# Name: count, dtype: int64

# %%
df1.loc[df1.Origin.isna(),"Origin"] = "Other"

# %%
df1.Origin.value_counts()
# Out:
# Origin
# Trong nước    824
# Nhập khẩu     484
# Other           7
# Name: count, dtype: int64

# %% [markdown]
# 6.Mileage

# %%
df1.Mileage.head()
# Out:
# 0    55.555 km
# 2     1.000 km
# 3        04 km
# 6    90.000 km
# 7    57.225 km
# Name: Mileage, dtype: object

# %%
df1.Mileage.isna().sum()
# Out:
# 5

# %%
df1.Mileage.describe()
# Out:
# count          1310
# unique          288
# top       60.000 km
# freq             58
# Name: Mileage, dtype: object

# %%
df1.loc[df1["Mileage"].isna(),"Mileage"] = "60.000 km"

# %%
df1['mileage_num'] = df1['Mileage'].str.replace('.', '', regex=False) \
                                  .str.replace(' km', '', regex=False) \
                                  .astype(int)

# %%
df1.head()
# Out:
#                                      Name  Year      Origin    Mileage  \
# 0       Mercedes-Benz GLC 200 4Matic 2021  2021  Trong nước  55.555 km
# 2              Kia Sonet 1.5 Premium 2024  2024  Trong nước   1.000 km
# 3  Ford Everest Titanium 2.0L AT 4WD 2019  2019   Nhập khẩu      04 km
# 6       Mercedes-Benz GLC 300 4Matic 2016  2016   Nhập khẩu  90.000 km
# 7                     Mazda 6 2.0 AT 2017  2017  Trong nước  57.225 km
#
#     Province     District Transmission Fuel_Type  Body_Type          Brand  \
# 0     Tp.HCM       Quận 7   Số tự động  Máy xăng      Other  Mercedes-Benz
# 2     Hà Nội  Nam Từ Liêm   Số tự động  Máy xăng  Crossover            Kia
# 3     Tp.HCM          NaN   Số tự động  Máy xăng        SUV           Ford
# 6     Hà Nội       Tây Hồ   Số tự động  Máy xăng        SUV  Mercedes-Benz
# 7  Hải Phòng       An Lão   Số tự động  Máy xăng      Sedan          Mazda
#
#     price_num  age  mileage_num
# 0  1389000000    4        55555
# 2   585000000    1         1000
# 3   810000000    6            4
# 6   885000000    9        90000
# 7   440000000    8        57225

# %%
df1 = df1.drop("Mileage",axis=1)

# %%
df1.columns
# Out:
# Index(['Name', 'Year', 'Origin', 'Province', 'District', 'Transmission',
#        'Fuel_Type', 'Body_Type', 'Brand', 'price_num', 'age', 'mileage_num'],
#       dtype='object')

# %% [markdown]
# 7.Province

# %%
df1.Province.head()
# Out:
# 0       Tp.HCM
# 2       Hà Nội
# 3       Tp.HCM
# 6       Hà Nội
# 7    Hải Phòng
# Name: Province, dtype: object

# %%
df1.Province.isna().sum()
# Out:
# 0

# %%
df1.Province.nunique()
# Out:
# 42

# %% [markdown]
# 8.District

# %%
df1.District.isna().sum()
# Out:
# 197

# %%
df1.District.describe()
# Out:
# count         1118
# unique          89
# top       Cầu Giấy
# freq           132
# Name: District, dtype: object

# %%
df1.loc[df1["District"].isna(),"District"] = "Other"

# %% [markdown]
# 9.Transmission

# %%
df1.Transmission.head()
# Out:
# 0    Số tự động
# 2    Số tự động
# 3    Số tự động
# 6    Số tự động
# 7    Số tự động
# Name: Transmission, dtype: object

# %%
df1.Transmission.isna().sum()
# Out:
# 0

# %%
df1.Transmission.unique()
# Out:
# array(['Số tự động', 'Số sàn'], dtype=object)

# %%
df1.Transmission.value_counts()
# Out:
# Transmission
# Số tự động    1143
# Số sàn         172
# Name: count, dtype: int64

# %% [markdown]
# 10.Fuel_Type

# %%
df1.Fuel_Type.head()
# Out:
# 0    Máy xăng
# 2    Máy xăng
# 3    Máy xăng
# 6    Máy xăng
# 7    Máy xăng
# Name: Fuel_Type, dtype: object

# %%
df1.Fuel_Type.value_counts()
# Out:
# Fuel_Type
# Máy xăng    1083
# Máy dầu      210
# Điện          15
# Hybrid         7
# Name: count, dtype: int64

# %%
df1.head()
# Out:
#                                      Name  Year      Origin   Province  \
# 0       Mercedes-Benz GLC 200 4Matic 2021  2021  Trong nước     Tp.HCM
# 2              Kia Sonet 1.5 Premium 2024  2024  Trong nước     Hà Nội
# 3  Ford Everest Titanium 2.0L AT 4WD 2019  2019   Nhập khẩu     Tp.HCM
# 6       Mercedes-Benz GLC 300 4Matic 2016  2016   Nhập khẩu     Hà Nội
# 7                     Mazda 6 2.0 AT 2017  2017  Trong nước  Hải Phòng
#
#       District Transmission Fuel_Type  Body_Type          Brand   price_num  \
# 0       Quận 7   Số tự động  Máy xăng      Other  Mercedes-Benz  1389000000
# 2  Nam Từ Liêm   Số tự động  Máy xăng  Crossover            Kia   585000000
# 3        Other   Số tự động  Máy xăng        SUV           Ford   810000000
# 6       Tây Hồ   Số tự động  Máy xăng        SUV  Mercedes-Benz   885000000
# 7       An Lão   Số tự động  Máy xăng      Sedan          Mazda   440000000
#
#    age  mileage_num
# 0    4        55555
# 2    1         1000
# 3    6            4
# 6    9        90000
# 7    8        57225

# %%
len(df1)
# Out:
# 1315

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1315 entries, 0 to 1489
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          1315 non-null   object
#  1   Year          1315 non-null   int32
#  2   Origin        1315 non-null   object
#  3   Province      1315 non-null   object
#  4   District      1315 non-null   object
#  5   Transmission  1315 non-null   object
#  6   Fuel_Type     1315 non-null   object
#  7   Body_Type     1315 non-null   object
#  8   Brand         1315 non-null   object
#  9   price_num     1315 non-null   int64
#  10  age           1315 non-null   int32
#  11  mileage_num   1315 non-null   int32
# dtypes: int32(3), int64(1), object(8)
# memory usage: 118.1+ KB

# %%
#  df.to_csv("../data/data_cleaned.csv", index=False, encoding='utf-8-sig')
#  print("Done! Cleaned data saved successfully.")
