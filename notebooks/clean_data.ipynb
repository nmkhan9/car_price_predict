# %%
import pandas as pd
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv
import warnings
warnings.filterwarnings("ignore")
import sys, os
sys.path.append(os.path.abspath(".."))
from config import ENGINE

# %%
engine = ENGINE

# %% [markdown]
# ### clean df1

# %%
df1 = pd.read_sql("SELECT * FROM car_data1", engine)

# %%
df1.head()
# Out:
#                                     Name           Price Năm SX  Kiểu dáng  \
# 0      Toyota Fortuner 2.4G 4x2 AT  2017       525 triệu   2017        SUV
# 1               Suzuki Swift 1.4 AT 2013       269 triệu   2013  Hatchback
# 2     Volvo XC60 B6 Ultimate Bright 2023  2 tỉ 190 triệu   2023        SUV
# 3  Hyundai Stargazer 1.5 AT Cao cấp 2022       455 triệu   2022        MPV
# 4                    Nissan X trail 2018       465 triệu   2018        SUV
#
#   Tình trạng     Xuất xứ    Km đã đi Tỉnh thành      Hộp số Nhiên liệu  \
# 0      Xe cũ   Nhập khẩu      135 km    Nghệ An      Số sàn    Máy dầu
# 1      Xe cũ   Nhập khẩu  132.000 km     Tp.HCM  Số tự động   Máy xăng
# 2      Xe cũ   Nhập khẩu      120 km     Hà Nội  Số tự động   Máy xăng
# 3      Xe cũ   Nhập khẩu   72.000 km    Long An  Số tự động   Máy xăng
# 4      Xe cũ  Trong nước  110.000 km    Long An  Số tự động   Máy xăng
#
#   Số tiền vay Thời gian vay Lãi xuất (%)  \
# 0         VNĐ      ThángNăm     ThángNăm
# 1         VNĐ      ThángNăm     ThángNăm
# 2         VNĐ      ThángNăm     ThángNăm
# 3         VNĐ      ThángNăm     ThángNăm
# 4         VNĐ      ThángNăm     ThángNăm
#
#                                            Loại hình Giá trị xe muốn mua  \
# 0  Trả góp đều hàng thángTrả góp đều, lãi tính tr...                 VNĐ
# 1  Trả góp đều hàng thángTrả góp đều, lãi tính tr...                 VNĐ
# 2  Trả góp đều hàng thángTrả góp đều, lãi tính tr...                 VNĐ
# 3  Trả góp đều hàng thángTrả góp đều, lãi tính tr...                 VNĐ
# 4  Trả góp đều hàng thángTrả góp đều, lãi tính tr...                 VNĐ
#
#   Quận huyện Full lịch sử hãng
# 0       None              None
# 1    Tân Phú              None
# 2  Long Biên              None
# 3       None              None
# 4     Tân An              None

# %%
df1.shape
# Out:
# (1490, 17)

# %%
df1 = df1.loc[:, (df1.nunique() > 1) | (df1.columns == "Tình trạng")]

# %%
threshold = 0.5
df1 = df1.loc[:, df1.isnull().mean() < threshold]

# %%
df1.columns
# Out:
# Index(['Name', 'Price', 'Năm SX', 'Kiểu dáng', 'Tình trạng', 'Xuất xứ',
#        'Km đã đi', 'Tỉnh thành', 'Hộp số', 'Nhiên liệu', 'Quận huyện'],
#       dtype='object')

# %%
df1.shape
# Out:
# (1490, 11)

# %%
df1 = df1.drop(["Tỉnh thành","Quận huyện","Hộp số"],axis=1)

# %%
df1.columns
# Out:
# Index(['Name', 'Price', 'Năm SX', 'Kiểu dáng', 'Tình trạng', 'Xuất xứ',
#        'Km đã đi', 'Nhiên liệu'],
#       dtype='object')

# %%
df1.rename(columns={
    'Name': 'name',
    'Price': 'price',
    'Tình trạng' : 'status',
    'Năm SX': 'year',
    'Kiểu dáng': 'body_type',
    'Xuất xứ': 'origin',
    'Km đã đi': 'mileage',
    'Nhiên liệu': 'fuel_type'
}, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1490 entries, 0 to 1489
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       1490 non-null   object
#  1   price      1490 non-null   object
#  2   year       1490 non-null   object
#  3   body_type  1376 non-null   object
#  4   status     1490 non-null   object
#  5   origin     1485 non-null   object
#  6   mileage    1484 non-null   object
#  7   fuel_type  1490 non-null   object
# dtypes: object(8)
# memory usage: 93.3+ KB

# %%
df1.isna().sum()
# Out:
# name           0
# price          0
# year           0
# body_type    114
# status         0
# origin         5
# mileage        6
# fuel_type      0
# dtype: int64

# %%
df1.head()
# Out:
#                                     name           price  year  body_type  \
# 0      Toyota Fortuner 2.4G 4x2 AT  2017       525 triệu  2017        SUV
# 1               Suzuki Swift 1.4 AT 2013       269 triệu  2013  Hatchback
# 2     Volvo XC60 B6 Ultimate Bright 2023  2 tỉ 190 triệu  2023        SUV
# 3  Hyundai Stargazer 1.5 AT Cao cấp 2022       455 triệu  2022        MPV
# 4                    Nissan X trail 2018       465 triệu  2018        SUV
#
#   status      origin     mileage fuel_type
# 0  Xe cũ   Nhập khẩu      135 km   Máy dầu
# 1  Xe cũ   Nhập khẩu  132.000 km  Máy xăng
# 2  Xe cũ   Nhập khẩu      120 km  Máy xăng
# 3  Xe cũ   Nhập khẩu   72.000 km  Máy xăng
# 4  Xe cũ  Trong nước  110.000 km  Máy xăng

# %% [markdown]
# 1. Name

# %%
df1.name.head()
# Out:
# 0        Toyota Fortuner 2.4G 4x2 AT  2017
# 1                 Suzuki Swift 1.4 AT 2013
# 2       Volvo XC60 B6 Ultimate Bright 2023
# 3    Hyundai Stargazer 1.5 AT Cao cấp 2022
# 4                      Nissan X trail 2018
# Name: name, dtype: object

# %%
df1["brand"] = df1["name"].str.strip().str.split().str[0]

# %%
df1["brand"] = df1["brand"].str.split("-").str[0]

# %%
df1.head()
# Out:
#                                     name           price  year  body_type  \
# 0      Toyota Fortuner 2.4G 4x2 AT  2017       525 triệu  2017        SUV
# 1               Suzuki Swift 1.4 AT 2013       269 triệu  2013  Hatchback
# 2     Volvo XC60 B6 Ultimate Bright 2023  2 tỉ 190 triệu  2023        SUV
# 3  Hyundai Stargazer 1.5 AT Cao cấp 2022       455 triệu  2022        MPV
# 4                    Nissan X trail 2018       465 triệu  2018        SUV
#
#   status      origin     mileage fuel_type    brand
# 0  Xe cũ   Nhập khẩu      135 km   Máy dầu   Toyota
# 1  Xe cũ   Nhập khẩu  132.000 km  Máy xăng   Suzuki
# 2  Xe cũ   Nhập khẩu      120 km  Máy xăng    Volvo
# 3  Xe cũ   Nhập khẩu   72.000 km  Máy xăng  Hyundai
# 4  Xe cũ  Trong nước  110.000 km  Máy xăng   Nissan

# %% [markdown]
# 2.Price

# %%
df1.price.head()
# Out:
# 0         525 triệu
# 1         269 triệu
# 2    2 tỉ 190 triệu
# 3         455 triệu
# 4         465 triệu
# Name: price, dtype: object

# %%
def convert_price(price_str):
    if not price_str or not isinstance(price_str, str):
        return None

    price_str = price_str.strip().lower()
    price = 0

    try:
        if "tỉ" in price_str:
            parts = price_str.split("tỉ")
            ty = float(parts[0].strip().replace(",", "."))
            price += ty * 1_000_000_000

            if len(parts) > 1 and "triệu" in parts[1]:
                trieu = float(parts[1].replace("triệu", "").strip().replace(",", "."))
                price += trieu * 1_000_000
        elif "triệu" in price_str:
            trieu = float(price_str.replace("triệu", "").strip().replace(",", "."))
            price += trieu * 1_000_000
        else:
            price = float(price_str.replace(",", "").strip())
        return int(price)
    except Exception:
        return None

# %%
df1["price"] = df1["price"].apply(convert_price)

# %%
df1.head()
# Out:
#                                     name       price  year  body_type status  \
# 0      Toyota Fortuner 2.4G 4x2 AT  2017   525000000  2017        SUV  Xe cũ
# 1               Suzuki Swift 1.4 AT 2013   269000000  2013  Hatchback  Xe cũ
# 2     Volvo XC60 B6 Ultimate Bright 2023  2190000000  2023        SUV  Xe cũ
# 3  Hyundai Stargazer 1.5 AT Cao cấp 2022   455000000  2022        MPV  Xe cũ
# 4                    Nissan X trail 2018   465000000  2018        SUV  Xe cũ
#
#        origin     mileage fuel_type    brand
# 0   Nhập khẩu      135 km   Máy dầu   Toyota
# 1   Nhập khẩu  132.000 km  Máy xăng   Suzuki
# 2   Nhập khẩu      120 km  Máy xăng    Volvo
# 3   Nhập khẩu   72.000 km  Máy xăng  Hyundai
# 4  Trong nước  110.000 km  Máy xăng   Nissan

# %%
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1

    filtered_df = df[(df[column] >= Q1 - 1.5 * IQR) & (df[column] <= Q3 + 1.5 * IQR)]
    return filtered_df

# %%
df1 = remove_outliers_iqr(df1, "price")

# %%
df1.shape
# Out:
# (1315, 9)

# %% [markdown]
# 3.Year

# %%
df1.year.head()
# Out:
# 0    2017
# 1    2013
# 3    2022
# 4    2018
# 5    2016
# Name: year, dtype: object

# %%
df1.year = df1.year.astype(int)

# %%
df1["age"] = 2025 - df1["year"]

# %% [markdown]
# 4.Body_Type

# %%
df1.body_type.unique()
# Out:
# array(['SUV', 'Hatchback', 'MPV', 'Sedan', 'Bán tải', 'Crossover', None,
#        'Sport Car', 'Van/Minivan', 'Xe tải', 'Convertible', 'Coupe',
#        'Minibus'], dtype=object)

# %%
df1.loc[df1["body_type"].isna() , "body_type"] = "Other"

# %% [markdown]
# 5.Origin

# %%
df1.origin.isna().sum()
# Out:
# 5

# %%
df1.origin.value_counts()
# Out:
# origin
# Trong nước    832
# Nhập khẩu     478
# Name: count, dtype: int64

# %%
df1.loc[df1.origin.isna(),"origin"] = "Other"

# %%
df1.origin.value_counts()
# Out:
# origin
# Trong nước    832
# Nhập khẩu     478
# Other           5
# Name: count, dtype: int64

# %% [markdown]
# 6.Mileage

# %%
df1.mileage.head()
# Out:
# 0        135 km
# 1    132.000 km
# 3     72.000 km
# 4    110.000 km
# 5     79.000 km
# Name: mileage, dtype: object

# %%
df1.mileage.isna().sum()
# Out:
# 6

# %%
df1.mileage.describe()
# Out:
# count          1309
# unique          314
# top       60.000 km
# freq             51
# Name: mileage, dtype: object

# %%
df1.loc[df1["mileage"].isna(),"mileage"] = "60.000 km"

# %%
df1['mileage'] = df1['mileage'].str.replace('.', '', regex=False) \
                                  .str.replace(' km', '', regex=False) \
                                  .astype(int)

# %%
df1.head()
# Out:
#                                     name      price  year  body_type status  \
# 0      Toyota Fortuner 2.4G 4x2 AT  2017  525000000  2017        SUV  Xe cũ
# 1               Suzuki Swift 1.4 AT 2013  269000000  2013  Hatchback  Xe cũ
# 3  Hyundai Stargazer 1.5 AT Cao cấp 2022  455000000  2022        MPV  Xe cũ
# 4                    Nissan X trail 2018  465000000  2018        SUV  Xe cũ
# 5         Mazda 3 Sedan 1.5L Luxury 2016  360000000  2016      Sedan  Xe cũ
#
#        origin  mileage fuel_type    brand  age
# 0   Nhập khẩu      135   Máy dầu   Toyota    8
# 1   Nhập khẩu   132000  Máy xăng   Suzuki   12
# 3   Nhập khẩu    72000  Máy xăng  Hyundai    3
# 4  Trong nước   110000  Máy xăng   Nissan    7
# 5   Nhập khẩu    79000  Máy xăng    Mazda    9

# %% [markdown]
# 7. Fuel type

# %%
df1.fuel_type.head()
# Out:
# 0     Máy dầu
# 1    Máy xăng
# 3    Máy xăng
# 4    Máy xăng
# 5    Máy xăng
# Name: fuel_type, dtype: object

# %%
df1.fuel_type = df1.fuel_type.str.split(" ").str[1]

# %%
df1.fuel_type.value_counts()
# Out:
# fuel_type
# xăng    1091
# dầu      203
# Name: count, dtype: int64

# %%
df1.fuel_type.unique()
# Out:
# array(['dầu', 'xăng', nan], dtype=object)

# %%
df1.loc[df1["fuel_type"].isna(),"fuel_type"] = "khác"

# %%
df1.head()
# Out:
#                                     name      price  year  body_type status  \
# 0      Toyota Fortuner 2.4G 4x2 AT  2017  525000000  2017        SUV  Xe cũ
# 1               Suzuki Swift 1.4 AT 2013  269000000  2013  Hatchback  Xe cũ
# 3  Hyundai Stargazer 1.5 AT Cao cấp 2022  455000000  2022        MPV  Xe cũ
# 4                    Nissan X trail 2018  465000000  2018        SUV  Xe cũ
# 5         Mazda 3 Sedan 1.5L Luxury 2016  360000000  2016      Sedan  Xe cũ
#
#        origin  mileage fuel_type    brand  age
# 0   Nhập khẩu      135       dầu   Toyota    8
# 1   Nhập khẩu   132000      xăng   Suzuki   12
# 3   Nhập khẩu    72000      xăng  Hyundai    3
# 4  Trong nước   110000      xăng   Nissan    7
# 5   Nhập khẩu    79000      xăng    Mazda    9

# %%
len(df1)
# Out:
# 1315

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1315 entries, 0 to 1489
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       1315 non-null   object
#  1   price      1315 non-null   int64
#  2   year       1315 non-null   int32
#  3   body_type  1315 non-null   object
#  4   status     1315 non-null   object
#  5   origin     1315 non-null   object
#  6   mileage    1315 non-null   int32
#  7   fuel_type  1315 non-null   object
#  8   brand      1315 non-null   object
#  9   age        1315 non-null   int32
# dtypes: int32(3), int64(1), object(6)
# memory usage: 97.6+ KB

# %% [markdown]
# ### clean df2

# %%
df2 = pd.read_sql("SELECT * FROM car_data2", engine)

# %%
df2.head()
# Out:
#                                                 Name Năm sản xuất  Tình trạng  \
# 0  Xe \n\t\t\t\n\t\t\t\t\t\t\tFord Territory \n\t...         2024  Xe đã dùng
# 1  Xe \n\t\t\t\n\t\t\t\t\t\t\tKia Sedona \n\t\t\t...         2020  Xe đã dùng
# 2  Xe \n\t\t\t\n\t\t\t\t\t\t\tFord Ranger \n\t\t\...         2023  Xe đã dùng
# 3  Xe \n\t\t\t\n\t\t\t\t\t\t\tMG 5 \n\t\t\t\t\t\t...         2024      Xe mới
# 4  Xe \n\t\t\t\n\t\t\t\t\t\t\tToyota Vios \n\t\t\...         2018  Xe đã dùng
#
#   Số Km đã đi             Xuất xứ           Kiểu dáng      Động cơ  \
# 0   10,000 Km  Lắp ráp trong nước                 SUV  Xăng  1.5 L
# 1   60,000 Km  Lắp ráp trong nước         Van/Minivan   Dầu  2.2 L
# 2      645 Km  Lắp ráp trong nước  Bán tải / Pickup   Dầu  2.0 L
# 3        None           Nhập khẩu               Sedan  Xăng  1.5 L
# 4   69,000 Km  Lắp ráp trong nước               Sedan  Xăng  1.5 L
#
#   Màu ngoại thất Màu nội thất
# 0          Trắng          Đen
# 1           Xanh          Kem
# 2             Đỏ          Nâu
# 3             Đỏ          Kem
# 4            Cát          Ghi

# %%
df2 = df2.drop(["Màu ngoại thất","Màu nội thất"],axis=1)

# %%
df2.head()
# Out:
#                                                 Name Năm sản xuất  Tình trạng  \
# 0  Xe \n\t\t\t\n\t\t\t\t\t\t\tFord Territory \n\t...         2024  Xe đã dùng
# 1  Xe \n\t\t\t\n\t\t\t\t\t\t\tKia Sedona \n\t\t\t...         2020  Xe đã dùng
# 2  Xe \n\t\t\t\n\t\t\t\t\t\t\tFord Ranger \n\t\t\...         2023  Xe đã dùng
# 3  Xe \n\t\t\t\n\t\t\t\t\t\t\tMG 5 \n\t\t\t\t\t\t...         2024      Xe mới
# 4  Xe \n\t\t\t\n\t\t\t\t\t\t\tToyota Vios \n\t\t\...         2018  Xe đã dùng
#
#   Số Km đã đi             Xuất xứ           Kiểu dáng      Động cơ
# 0   10,000 Km  Lắp ráp trong nước                 SUV  Xăng  1.5 L
# 1   60,000 Km  Lắp ráp trong nước         Van/Minivan   Dầu  2.2 L
# 2      645 Km  Lắp ráp trong nước  Bán tải / Pickup   Dầu  2.0 L
# 3        None           Nhập khẩu               Sedan  Xăng  1.5 L
# 4   69,000 Km  Lắp ráp trong nước               Sedan  Xăng  1.5 L

# %%
df2.rename(columns={
    'Name': 'name',
    'Tình trạng' : 'status',
    'Năm sản xuất': 'year',
    'Kiểu dáng': 'body_type',
    'Xuất xứ': 'origin',
    'Số Km đã đi': 'mileage',
    'Động cơ': 'fuel_type'
}, inplace=True)

# %%
df2.columns
# Out:
# Index(['name', 'year', 'status', 'mileage', 'origin', 'body_type',
#        'fuel_type'],
#       dtype='object')

# %% [markdown]
# 1. Name

# %%
import re

def clean_name(text):
    if not isinstance(text, str):
        return None
    text = re.sub(r"Xe\s+", "", text)  
    text = re.sub(r"\s+", " ", text) 
    return text.strip()

# %%
df2["name"] = df2["name"].apply(clean_name)

# %%
def split_name_price(full_name):
    if not isinstance(full_name, str):
        return None, None
    
    if " - " in full_name:
        parts = full_name.rsplit(" - ", 1)
        car = parts[0].strip()
        price_raw = parts[1].strip().lower()
        return car, price_raw
    return full_name, None

# %%
df2[["name", "price"]] = df2["name"].apply(
    lambda x: pd.Series(split_name_price(x))
)

# %%
df2.head()
# Out:
#                                     name  year      status    mileage  \
# 0  Ford Territory Titanium X 1.5 AT 2024  2024  Xe đã dùng  10,000 Km
# 1         Kia Sedona 2.2 DAT Luxury 2020  2020  Xe đã dùng  60,000 Km
# 2       Ford Ranger XLS 2.0L 4x2 AT 2023  2023  Xe đã dùng     645 Km
# 3                       MG 5 1.5 MT 2024  2024      Xe mới       None
# 4               Toyota Vios 1.5E MT 2018  2018  Xe đã dùng  69,000 Km
#
#                origin           body_type    fuel_type      price
# 0  Lắp ráp trong nước                 SUV  Xăng  1.5 L  865 triệu
# 1  Lắp ráp trong nước         Van/Minivan   Dầu  2.2 L  835 triệu
# 2  Lắp ráp trong nước  Bán tải / Pickup   Dầu  2.0 L  639 triệu
# 3           Nhập khẩu               Sedan  Xăng  1.5 L  305 triệu
# 4  Lắp ráp trong nước               Sedan  Xăng  1.5 L  275 triệu

# %%
df2["brand"] = df2["name"].str.strip().str.split().str[0]

# %% [markdown]
# 2. Price

# %%
def cv_price(price_str):
    if not isinstance(price_str, str):
        return None
    price_str = price_str.strip().lower()
    price = 0

    try:
        ty_match = re.search(r"(\d+)[\.,]?\d*\s*t[ỷỉ]", price_str)
        if ty_match:
            ty = int(ty_match.group(1))
            price += ty * 1_000_000_000

        trieu_match = re.search(r"(\d+)[\.,]?\d*\s*triệu", price_str)
        if trieu_match:
            trieu = int(trieu_match.group(1))
            price += trieu * 1_000_000

        return price if price > 0 else None

    except Exception as e:
        return None

# %%
df2["price"] = df2["price"].apply(cv_price)

# %%
df2.head()
# Out:
#                                     name  year      status    mileage  \
# 0  Ford Territory Titanium X 1.5 AT 2024  2024  Xe đã dùng  10,000 Km
# 1         Kia Sedona 2.2 DAT Luxury 2020  2020  Xe đã dùng  60,000 Km
# 2       Ford Ranger XLS 2.0L 4x2 AT 2023  2023  Xe đã dùng     645 Km
# 3                       MG 5 1.5 MT 2024  2024      Xe mới       None
# 4               Toyota Vios 1.5E MT 2018  2018  Xe đã dùng  69,000 Km
#
#                origin           body_type    fuel_type      price   brand
# 0  Lắp ráp trong nước                 SUV  Xăng  1.5 L  865000000    Ford
# 1  Lắp ráp trong nước         Van/Minivan   Dầu  2.2 L  835000000     Kia
# 2  Lắp ráp trong nước  Bán tải / Pickup   Dầu  2.0 L  639000000    Ford
# 3           Nhập khẩu               Sedan  Xăng  1.5 L  305000000      MG
# 4  Lắp ráp trong nước               Sedan  Xăng  1.5 L  275000000  Toyota

# %%
df2 = remove_outliers_iqr(df2, "price")

# %%
len(df2)
# Out:
# 2578

# %% [markdown]
# 3. Year

# %%
df2["year"] =df2["year"].astype(int)

# %%
df2["age"] = 2025 - df2["year"]

# %%
df2.head()
# Out:
#                                     name  year      status    mileage  \
# 0  Ford Territory Titanium X 1.5 AT 2024  2024  Xe đã dùng  10,000 Km
# 1         Kia Sedona 2.2 DAT Luxury 2020  2020  Xe đã dùng  60,000 Km
# 2       Ford Ranger XLS 2.0L 4x2 AT 2023  2023  Xe đã dùng     645 Km
# 3                       MG 5 1.5 MT 2024  2024      Xe mới       None
# 4               Toyota Vios 1.5E MT 2018  2018  Xe đã dùng  69,000 Km
#
#                origin           body_type    fuel_type      price   brand  age
# 0  Lắp ráp trong nước                 SUV  Xăng  1.5 L  865000000    Ford    1
# 1  Lắp ráp trong nước         Van/Minivan   Dầu  2.2 L  835000000     Kia    5
# 2  Lắp ráp trong nước  Bán tải / Pickup   Dầu  2.0 L  639000000    Ford    2
# 3           Nhập khẩu               Sedan  Xăng  1.5 L  305000000      MG    1
# 4  Lắp ráp trong nước               Sedan  Xăng  1.5 L  275000000  Toyota    7

# %% [markdown]
# 4. Status

# %%
df2.status.unique()
# Out:
# array(['Xe đã dùng', 'Xe mới'], dtype=object)

# %%
df2.loc[df2.status == "Xe đã dùng","status"] = "Xe cũ"

# %%
df2.status.unique()
# Out:
# array(['Xe cũ', 'Xe mới'], dtype=object)

# %% [markdown]
# 5. Mileage

# %%
df2.groupby("status")["mileage"].describe()
# Out:
#        count unique   top freq
# status
# Xe cũ   2145    337  0 Km  190
# Xe mới     0      0   NaN  NaN

# %%
df2.loc[df2["status"].isin(["Xe cũ", "Xe mới"]) & df2["mileage"].isna(), "mileage"] = "0 Km"

# %%
df2.head()
# Out:
#                                     name  year  status    mileage  \
# 0  Ford Territory Titanium X 1.5 AT 2024  2024   Xe cũ  10,000 Km
# 1         Kia Sedona 2.2 DAT Luxury 2020  2020   Xe cũ  60,000 Km
# 2       Ford Ranger XLS 2.0L 4x2 AT 2023  2023   Xe cũ     645 Km
# 3                       MG 5 1.5 MT 2024  2024  Xe mới       0 Km
# 4               Toyota Vios 1.5E MT 2018  2018   Xe cũ  69,000 Km
#
#                origin           body_type    fuel_type      price   brand  age
# 0  Lắp ráp trong nước                 SUV  Xăng  1.5 L  865000000    Ford    1
# 1  Lắp ráp trong nước         Van/Minivan   Dầu  2.2 L  835000000     Kia    5
# 2  Lắp ráp trong nước  Bán tải / Pickup   Dầu  2.0 L  639000000    Ford    2
# 3           Nhập khẩu               Sedan  Xăng  1.5 L  305000000      MG    1
# 4  Lắp ráp trong nước               Sedan  Xăng  1.5 L  275000000  Toyota    7

# %%
df2['mileage'] = (
    df2['mileage']
    .str.replace(',', '', regex=False)   
    .str.replace(' Km', '', regex=False)    
    .str.strip()                         
    .astype(float)                      
)

# %%
df2.head()
# Out:
#                                     name  year  status  mileage  \
# 0  Ford Territory Titanium X 1.5 AT 2024  2024   Xe cũ  10000.0
# 1         Kia Sedona 2.2 DAT Luxury 2020  2020   Xe cũ  60000.0
# 2       Ford Ranger XLS 2.0L 4x2 AT 2023  2023   Xe cũ    645.0
# 3                       MG 5 1.5 MT 2024  2024  Xe mới      0.0
# 4               Toyota Vios 1.5E MT 2018  2018   Xe cũ  69000.0
#
#                origin           body_type    fuel_type      price   brand  age
# 0  Lắp ráp trong nước                 SUV  Xăng  1.5 L  865000000    Ford    1
# 1  Lắp ráp trong nước         Van/Minivan   Dầu  2.2 L  835000000     Kia    5
# 2  Lắp ráp trong nước  Bán tải / Pickup   Dầu  2.0 L  639000000    Ford    2
# 3           Nhập khẩu               Sedan  Xăng  1.5 L  305000000      MG    1
# 4  Lắp ráp trong nước               Sedan  Xăng  1.5 L  275000000  Toyota    7

# %% [markdown]
# 6. Origin

# %%
df2["origin"].unique()
# Out:
# array(['Lắp ráp trong nước', 'Nhập khẩu'], dtype=object)

# %%
df2.loc[df2["origin"]=="Lắp ráp trong nước","origin"] = 'Trong nước'

# %%
df2["origin"].unique()
# Out:
# array(['Trong nước', 'Nhập khẩu'], dtype=object)

# %% [markdown]
# 7. body_type

# %%
df2["body_type"].isna().sum()
# Out:
# 0

# %% [markdown]
# 8. fuel_type

# %%
df2["fuel_type"].unique()
# Out:
# array(['Xăng  1.5 L', 'Dầu  2.2 L', 'Dầu  2.0 L', 'Xăng  2.0 L',
#        'Xăng  2.5 L', 'Điện  0.2 L', 'Xăng  1.25 L', 'Xăng  2.4 L',
#        'Dầu  2.5 L', 'Dầu  2.8 L', 'Xăng  1.6 L', 'Xăng  1.0 L',
#        'Xăng  1.8 L', 'Xăng  1.2 L', 'Dầu  3.2 L', 'Xăng  5.0 L',
#        'Xăng  6.2 L', 'Xăng  2.7 L', 'Xăng  1.4 L', 'Xăng  3.3 L',
#        'Xăng  2.3 L', 'Điện', 'Xăng  4.6 L', 'Điện  0.6 L', 'Xăng  3.0 L',
#        'Xăng  1.3 L', 'Hybrid  2.5 L', 'Xăng  3.5 L', 'Điện  0.3 L',
#        'Dầu  1.9 L', 'Xăng  5.5 L', 'Dầu  3.0 L', 'Xăng  4.7 L',
#        'Dầu  2.4 L', 'Xăng  4.8 L', 'Dầu  1.5 L', 'Dầu', 'Điện  8.3 L',
#        'Hybrid  1.8 L', 'Dầu  2.1 L', 'Hybrid  2.0 L', 'Xăng  3.6 L',
#        'Dầu  2.3 L', 'Xăng  5.7 L', 'Điện  0.1 L', 'Hybrid  1.2 L',
#        'Điện  0.4 L', 'Dầu  10.0 L', 'Xăng  4.4 L', 'Xăng  2.2 L',
#        'Hybrid  1.5 L', 'Xăng  6.0 L', 'Dầu  5.2 L', 'Xăng  4.0 L',
#        'Xăng', 'Hybrid  3.5 L', 'Xăng  0.8 L', 'Xăng  1.1 L',
#        'Xăng  4.2 L', 'Xăng  3.7 L', 'Điện  0.5 L', 'Xăng  5.4 L'],
#       dtype=object)

# %%
df2["fuel_type"] = df2["fuel_type"].str.strip().str.split().str[0]

# %%
df2["fuel_type"].unique()
# Out:
# array(['Xăng', 'Dầu', 'Điện', 'Hybrid'], dtype=object)

# %%
df2["fuel_type"] = df2["fuel_type"].str.lower()

# %%
df2["fuel_type"].unique()
# Out:
# array(['xăng', 'dầu', 'điện', 'hybrid'], dtype=object)

# %%
df1["fuel_type"].unique()
# Out:
# array(['dầu', 'xăng', 'khác'], dtype=object)

# %%
df_merged = pd.concat([df1, df2], ignore_index=True)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3893 entries, 0 to 3892
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       3893 non-null   object
#  1   price      3893 non-null   int64
#  2   year       3893 non-null   int32
#  3   body_type  3893 non-null   object
#  4   status     3893 non-null   object
#  5   origin     3893 non-null   object
#  6   mileage    3893 non-null   float64
#  7   fuel_type  3893 non-null   object
#  8   brand      3893 non-null   object
#  9   age        3893 non-null   int32
# dtypes: float64(1), int32(2), int64(1), object(6)
# memory usage: 273.9+ KB

# %%
df = df_merged

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3893 entries, 0 to 3892
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       3893 non-null   object
#  1   price      3893 non-null   int64
#  2   year       3893 non-null   int32
#  3   body_type  3893 non-null   object
#  4   status     3893 non-null   object
#  5   origin     3893 non-null   object
#  6   mileage    3893 non-null   float64
#  7   fuel_type  3893 non-null   object
#  8   brand      3893 non-null   object
#  9   age        3893 non-null   int32
# dtypes: float64(1), int32(2), int64(1), object(6)
# memory usage: 273.9+ KB

# %%
df = remove_outliers_iqr(df, "price")

# %%
df["status"].unique()
# Out:
# array(['Xe cũ', 'Xe mới'], dtype=object)

# %%
df["origin"].unique()
# Out:
# array(['Nhập khẩu', 'Trong nước', 'Other'], dtype=object)

# %%
df["fuel_type"].unique()
# Out:
# array(['dầu', 'xăng', 'khác', 'điện', 'hybrid'], dtype=object)

# %%
print(list(df["body_type"].unique()))
# Out:
# ['SUV', 'Hatchback', 'MPV', 'Sedan', 'Bán tải', 'Crossover', 'Other', 'Sport Car', 'Van/Minivan', 'Xe tải', 'Convertible', 'Coupe', 'Minibus', 'Bán tải / Pickup', 'Truck', 'Convertible/Cabriolet', 'Wagon']

# %%
body_type_mapping = {
    'Bán tải / Pickup': 'Bán tải',
    'Truck': 'Xe tải',
    'Convertible/Cabriolet': 'Convertible',
    'Sport Car': 'Coupe',
    'Van/Minivan': 'MPV',
    'Other': 'Khác'
}

# %%
df["body_type"] = df["body_type"].replace(body_type_mapping)

# %%
df["body_type"].unique()
# Out:
# array(['SUV', 'Hatchback', 'MPV', 'Sedan', 'Bán tải', 'Crossover', 'Khác',
#        'Coupe', 'Xe tải', 'Convertible', 'Minibus', 'Wagon'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3592 entries, 0 to 3891
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       3592 non-null   object
#  1   price      3592 non-null   int64
#  2   year       3592 non-null   int32
#  3   body_type  3592 non-null   object
#  4   status     3592 non-null   object
#  5   origin     3592 non-null   object
#  6   mileage    3592 non-null   float64
#  7   fuel_type  3592 non-null   object
#  8   brand      3592 non-null   object
#  9   age        3592 non-null   int32
# dtypes: float64(1), int32(2), int64(1), object(6)
# memory usage: 280.6+ KB

# %%
df.to_sql("car_data_cleaned", engine, index=False, if_exists="append")
print(f"✅ Saved {len(df)} rows into car_data_cleaned")
# Out:
# ✅ Saved 3592 rows into car_data_cleaned

# %%
df1_demo = pd.read_sql("SELECT * FROM car_data1 LIMIT 5", engine)

# %%
df2_demo = pd.read_sql("SELECT * FROM car_data2 LIMIT 5", engine)

# %%
df_demo = pd.read_sql("SELECT * FROM car_data_cleaned LIMIT 5", engine)

# %%
df1_demo.to_csv("../data/cars_data.csv", index=False, encoding="utf-8-sig")

# %%
df2_demo.to_csv("../data/cars_data2.csv", index=False, encoding="utf-8-sig")

# %%
df_demo.to_csv("../data/data_cleaned.csv", index=False, encoding="utf-8-sig")
